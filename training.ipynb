# %%
import pandas as pd
df = pd.read_csv("labelled_data_period1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1229 entries, 0 to 1228
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1229 non-null   int64
#  1   Date                1229 non-null   object
#  2   Open                1229 non-null   float64
#  3   High                1229 non-null   float64
#  4   Low                 1229 non-null   float64
#  5   Close               1229 non-null   float64
#  6   Adj Close           1229 non-null   float64
#  7   Volume              1229 non-null   int64
#  8   percentile_last_30  1229 non-null   float64
#  9   Open_t1             1229 non-null   float64
#  10  High_t1             1229 non-null   float64
#  11  Low_t1              1229 non-null   float64
#  12  Close_t1            1229 non-null   float64
#  13  Adj Close_t1        1229 non-null   float64
#  14  Volume_t1           1229 non-null   float64
#  15  T10Y2Y              1229 non-null   float64
#  16  T10YIE              1229 non-null   float64
#  17  DFF                 1229 non-null   float64
#  18  VIXCLS              1229 non-null   float64
#  19  Open_SP500          1229 non-null   float64
#  20  High_SP500          1229 non-null   float64
#  21  Low_SP500           1229 non-null   float64
#  22  Close_SP500         1229 non-null   float64
#  23  Adj Close_SP500     1229 non-null   float64
#  24  Volume_SP500        1229 non-null   int64
#  25  USRECD              1229 non-null   int64
# dtypes: float64(21), int64(4), object(1)
# memory usage: 249.8+ KB

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume  \
# 0  2005-02-15  44.150002  44.529999  43.790001  43.950001  43.950001  165399
# 1  2005-02-16  43.990002  44.660000  43.910000  44.450001  44.450001  232170
# 2  2005-02-17  44.320000  44.520000  43.509998  43.520000  43.520000  225170
# 3  2005-02-18  43.380001  43.730000  42.959999  43.009998  43.009998  259199
# 4  2005-02-22  43.009998  43.400002  42.250000  42.610001  42.610001  280175
#
#    percentile_last_30    Open_t1    High_t1  ...  T10YIE   DFF  VIXCLS  \
# 0           56.666667  44.650002  44.930000  ...    2.49  2.53   11.27
# 1           76.666667  44.150002  44.529999  ...    2.51  2.48   11.10
# 2           50.000000  43.990002  44.660000  ...    2.54  2.50   11.77
# 3           43.333333  44.320000  44.520000  ...    2.60  2.51   11.18
# 4           40.000000  43.380001  43.730000  ...    2.62  2.57   13.14
#
#     Open_SP500   High_SP500    Low_SP500  Close_SP500  Adj Close_SP500  \
# 0  1206.140015  1212.439941  1205.520020  1210.119995      1210.119995
# 1  1210.119995  1212.439941  1205.060059  1210.339966      1210.339966
# 2  1210.339966  1211.329956  1200.739990  1200.750000      1200.750000
# 3  1200.750000  1202.920044  1197.349976  1201.589966      1201.589966
# 4  1201.589966  1202.479980  1184.160034  1184.160034      1184.160034
#
#    Volume_SP500  USRECD
# 0    1527080000       0
# 1    1490100000       0
# 2    1580120000       0
# 3    1551200000       0
# 4    1744940000       0
#
# [5 rows x 25 columns]

# %%
#change the position of cols
#cols = [cols[7]] + cols[0:7] + cols[8:]
#df = df[cols]
#df.head()

# %%
df.columns[1:24]
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'percentile_last_30', 'Open_t1', 'High_t1', 'Low_t1', 'Close_t1',
#        'Adj Close_t1', 'Volume_t1', 'T10Y2Y', 'T10YIE', 'DFF', 'VIXCLS',
#        'Open_SP500', 'High_SP500', 'Low_SP500', 'Close_SP500',
#        'Adj Close_SP500', 'Volume_SP500'],
#       dtype='object')

# %%
# convert datatypes of all cols to int or float
'''df.columns[1:24]
df.dtypes
df['T10Y2Y'] = df['T10Y2Y'].replace('.', pd.np.nan)
df['T10Y2Y'] = df['T10Y2Y'].astype(float)
df['T10YIE'] = df['T10YIE'].replace('.', pd.np.nan)
df['T10YIE'] = df['T10YIE'].astype(float)
df.columns[1:24]
df.dtypes
df = df.dropna()
df.head()
'''
# Out:
# "df.columns[1:24]\ndf.dtypes\ndf['T10Y2Y'] = df['T10Y2Y'].replace('.', pd.np.nan)\ndf['T10Y2Y'] = df['T10Y2Y'].astype(float)\ndf['T10YIE'] = df['T10YIE'].replace('.', pd.np.nan)\ndf['T10YIE'] = df['T10YIE'].astype(float)\ndf.columns[1:24]\ndf.dtypes\ndf = df.dropna()\ndf.head()\n"

# %% [markdown]
# ### Scale the data

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

#scaler = StandardScaler()

scaler = MinMaxScaler()
feature_columns = df.columns[1:24]
label = df.columns[24:25]
#print(feature_columns)

df[feature_columns] = scaler.fit_transform(df[feature_columns])
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume  \
# 0  2005-02-15  0.554047  0.453915  0.682126  0.591364   0.591364  0.015858
# 1  2005-02-16  0.551298  0.455755  0.684668  0.600630   0.600630  0.024765
# 2  2005-02-17  0.556969  0.453773  0.676197  0.583395   0.583395  0.023831
# 3  2005-02-18  0.540815  0.442588  0.664549  0.573944   0.573944  0.028371
# 4  2005-02-22  0.534456  0.437916  0.649513  0.566531   0.566531  0.031169
#
#    percentile_last_30   Open_t1   High_t1  ...    T10YIE       DFF    VIXCLS  \
# 0            0.566667  0.562640  0.459578  ...  0.900735  0.462687  0.019445
# 1            0.766667  0.554047  0.453915  ...  0.908088  0.453358  0.017049
# 2            0.500000  0.551298  0.455755  ...  0.919118  0.457090  0.026490
# 3            0.433333  0.556969  0.453773  ...  0.941176  0.458955  0.018177
# 4            0.400000  0.540815  0.442588  ...  0.948529  0.470149  0.045794
#
#    Open_SP500  High_SP500  Low_SP500  Close_SP500  Adj Close_SP500  \
# 0    0.594852    0.587146   0.606221     0.600470         0.600470
# 1    0.599345    0.587146   0.605703     0.600718         0.600718
# 2    0.599594    0.585886   0.600842     0.589926         0.589926
# 3    0.588766    0.576338   0.597027     0.590871         0.590871
# 4    0.589714    0.575838   0.582185     0.571257         0.571257
#
#    Volume_SP500  USRECD
# 0      0.074748       0
# 1      0.071302       0
# 2      0.079690       0
# 3      0.076995       0
# 4      0.095049       0
#
# [5 rows x 25 columns]

# %% [markdown]
# Performing scaling for Period 2 as well:

# %%
period_2_df = pd.read_csv('labelled_data_period2.csv', index_col=[0])

scaler = MinMaxScaler()
feature_columns = period_2_df.columns[1:24]
label = period_2_df.columns[24:25]

period_2_df[feature_columns] = scaler.fit_transform(period_2_df[feature_columns])
period_2_df.to_csv('labelled_scaled_period2.csv')
period_2_df.head()
# Out:
#           Date      Open      High       Low     Close  Adj Close    Volume  \
# 30  2020-02-14  0.347160  0.349858  0.354052  0.351192   0.351192  0.003255
# 31  2020-02-18  0.346792  0.347252  0.347124  0.345481   0.345481  0.003274
# 32  2020-02-19  0.345281  0.349727  0.351356  0.353272   0.353272  0.003149
# 33  2020-02-20  0.346516  0.354383  0.352805  0.358308   0.358308  0.004623
# 34  2020-02-21  0.352061  0.353137  0.348110  0.345891   0.345891  0.006641
#
#     percentile_last_30   Open_t1   High_t1  ...    T10YIE       DFF    VIXCLS  \
# 30            0.966667  0.344464  0.347865  ...  0.460317  0.321503  0.000000
# 31            0.800000  0.347040  0.349858  ...  0.456349  0.323591  0.016664
# 32            1.000000  0.346672  0.347252  ...  0.456349  0.323591  0.010143
# 33            1.000000  0.345161  0.349727  ...  0.448413  0.323591  0.027242
# 34            0.733333  0.346396  0.354383  ...  0.440476  0.321503  0.049268
#
#     Open_SP500  High_SP500  Low_SP500  Close_SP500  Adj Close_SP500  \
# 30    0.432560    0.428915   0.453713     0.446537         0.446537
# 31    0.428964    0.426659   0.449640     0.442680         0.442680
# 32    0.433479    0.434010   0.458612     0.448878         0.448878
# 33    0.433503    0.432275   0.444003     0.443829         0.443829
# 34    0.425567    0.420999   0.439146     0.429965         0.429965
#
#     Volume_SP500  USRECD
# 30      0.207162       0
# 31      0.247149       0
# 32      0.230680       0
# 33      0.279650       0
# 34      0.266300       0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Split the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# First extract our test data and store it in x_test, y_test
features = df[feature_columns].to_numpy()
labels = df[label].to_numpy()
_x, x_test, _y, y_test = train_test_split(features, labels, test_size=0.10, random_state=42) #_x is the rest of the data

# set k = 5
k = 5

kfold_spliiter = KFold(n_splits=k)

folds_data = [] # this is an inefficient way but still do it

fold = 1
for train_index, validation_index in kfold_spliiter.split(_x):
    x_train , x_valid = _x[train_index,:],_x[validation_index,:]
    y_train , y_valid = _y[train_index,:] , _y[validation_index,:]
    print (f"Fold {fold} training data shape = {(x_train.shape,y_train.shape)}")
    print (f"Fold {fold} validation data shape = {(x_valid.shape,y_valid.shape)}")
    fold+=1
    folds_data.append((x_train,y_train,x_valid,y_valid))
# Out:
# Fold 1 training data shape = ((884, 23), (884, 1))
# Fold 1 validation data shape = ((222, 23), (222, 1))
# Fold 2 training data shape = ((885, 23), (885, 1))
# Fold 2 validation data shape = ((221, 23), (221, 1))
# Fold 3 training data shape = ((885, 23), (885, 1))
# Fold 3 validation data shape = ((221, 23), (221, 1))
# Fold 4 training data shape = ((885, 23), (885, 1))
# Fold 4 validation data shape = ((221, 23), (221, 1))
# Fold 5 training data shape = ((885, 23), (885, 1))
# Fold 5 validation data shape = ((221, 23), (221, 1))

# %% [markdown]
# ### Train the model

# %%
# Now let's define our models
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier


# LR with no regularizer
lr_vanilla = LogisticRegression(penalty='none')
lr_L2 = LogisticRegression(penalty="l2")
svm_linear = SVC(kernel="linear")
dt = DecisionTreeClassifier()
rf = RandomForestClassifier(random_state=23) # some random seed for reproducibility
grad_boost = GradientBoostingClassifier()
voting = VotingClassifier(estimators=[("1",lr_vanilla),("2",svm_linear),("3",dt)])



svm_linear = SVC(kernel="linear")
svm_poly = SVC(kernel="poly",degree=2)

# Keep all the models in a dictionary

all_models = {"lr_vanilla":lr_vanilla, 
              "lr_L2":lr_L2,
              "svm_linear":svm_linear,
              "svm_poly":svm_poly,
             "decision_tree":dt,
              "random_forest":rf,
              "grad_boost":grad_boost,
              "voting":voting}

# %%
best_validation_accuracy = 0
best_model_name = ""
best_model = None

# Iterate over all models
for model_name in all_models.keys():
    
    print (f"Evaluating {model_name} ...")
    model = all_models[model_name]
    
    # Let's store training and validation accuracies for all folds
    train_acc_for_all_folds = []
    valid_acc_for_all_folds = []
    
    #Iterate over all folds
    for i, fold in enumerate(folds_data):
        x_train, y_train, x_valid, y_valid = fold

        # Train the model
        _ = model.fit(x_train,y_train.flatten())

        # Evluate model on training data
        y_pred_train = model.predict(x_train)
        
        # Evaluate the model on validation data
        y_pred_valid = model.predict(x_valid)
        
        # Compute training accuracy
        train_acc = accuracy_score(y_pred_train , y_train.flatten())
        
        # Store training accuracy for each folds
        train_acc_for_all_folds.append(train_acc)
        
        # Compute validation accuracy
        valid_acc = accuracy_score(y_pred_valid , y_valid.flatten())

        # Store validation accuracy for each folds
        valid_acc_for_all_folds.append(valid_acc)
    
    #average training accuracy across k folds
    avg_training_acc = sum(train_acc_for_all_folds)/k
    
    print (f"Average training accuracy for model {model_name} = {avg_training_acc}")
    
    #average validation accuracy across k folds
    avg_validation_acc = sum(valid_acc_for_all_folds)/k
    
    print (f"Average validation accuracy for model {model_name} = {avg_validation_acc}")
    
    # Select best model based on average validation accuracy
    if avg_validation_acc > best_validation_accuracy:
        best_validation_accuracy = avg_validation_acc
        best_model_name = model_name
        best_model = model
    print (f"-----------------------------------")

print (f"Best model for the task is {best_model_name} which offers the validation accuracy of {best_validation_accuracy}")
# Out:
# Evaluating lr_vanilla ...
# Average training accuracy for model lr_vanilla = 0.925858322468492
# Average validation accuracy for model lr_vanilla = 0.9195181606946313
# -----------------------------------
# Evaluating lr_L2 ...
# Average training accuracy for model lr_L2 = 0.8399644655776262
# Average validation accuracy for model lr_L2 = 0.8354286413109943
# -----------------------------------
# Evaluating svm_linear ...
# c:\Users\micha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\micha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\micha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\micha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\micha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Average training accuracy for model svm_linear = 0.8788419357312677
# Average validation accuracy for model svm_linear = 0.8706942236354
# -----------------------------------
# Evaluating svm_poly ...
# Average training accuracy for model svm_poly = 0.9771702840197356
# Average validation accuracy for model svm_poly = 0.9801149565855448
# -----------------------------------
# Evaluating decision_tree ...
# Average training accuracy for model decision_tree = 1.0
# Average validation accuracy for model decision_tree = 0.9846276140393787
# -----------------------------------
# Evaluating random_forest ...
# Average training accuracy for model random_forest = 1.0
# Average validation accuracy for model random_forest = 0.9945742122212711
# -----------------------------------
# Evaluating grad_boost ...
# Average training accuracy for model grad_boost = 1.0
# Average validation accuracy for model grad_boost = 0.9936733113203701
# -----------------------------------
# Evaluating voting ...
# c:\Users\micha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\micha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\micha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\micha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Average training accuracy for model voting = 0.9656420482143313
# Average validation accuracy for model voting = 0.9502629326158738
# -----------------------------------
# Best model for the task is random_forest which offers the validation accuracy of 0.9945742122212711
# c:\Users\micha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import pandas as pd
df_test = pd.read_csv("labelled_scaled_period2.csv")

# %%
df_test
# Out:
#      Unnamed: 0        Date      Open      High       Low     Close  \
# 0            30  2020-02-14  0.347160  0.349858  0.354052  0.351192
# 1            31  2020-02-18  0.346792  0.347252  0.347124  0.345481
# 2            32  2020-02-19  0.345281  0.349727  0.351356  0.353272
# 3            33  2020-02-20  0.346516  0.354383  0.352805  0.358308
# 4            34  2020-02-21  0.352061  0.353137  0.348110  0.345891
# ..          ...         ...       ...       ...       ...       ...
# 781         811  2023-03-23  0.138814  0.138102  0.142235  0.139989
# 782         812  2023-03-24  0.138814  0.138102  0.142235  0.139989
# 783         813  2023-03-27  0.138814  0.138102  0.142235  0.139989
# 784         814  2023-03-28  0.000184  0.000000  0.000000  0.000000
# 785         815  2023-03-29  0.000000  0.000721  0.000431  0.000755
#
#      Adj Close    Volume  percentile_last_30   Open_t1  ...    T10YIE  \
# 0     0.351192  0.003255            0.966667  0.344464  ...  0.460317
# 1     0.345481  0.003274            0.800000  0.347040  ...  0.456349
# 2     0.353272  0.003149            1.000000  0.346672  ...  0.456349
# 3     0.358308  0.004623            1.000000  0.345161  ...  0.448413
# 4     0.345891  0.006641            0.733333  0.346396  ...  0.440476
# ..         ...       ...                 ...       ...  ...       ...
# 781   0.139989  0.000000            0.183333  0.138656  ...  0.670635
# 782   0.139989  0.000000            0.200000  0.138656  ...  0.682540
# 783   0.139989  0.000000            0.216667  0.138656  ...  0.690476
# 784   0.000000  1.000000            0.000000  0.138656  ...  0.718254
# 785   0.000755  0.797846            0.033333  0.000000  ...  0.726190
#
#           DFF    VIXCLS  Open_SP500  High_SP500  Low_SP500  Close_SP500  \
# 0    0.321503  0.000000    0.432560    0.428915   0.453713     0.446537
# 1    0.323591  0.016664    0.428964    0.426659   0.449640     0.442680
# 2    0.323591  0.010143    0.433479    0.434010   0.458612     0.448878
# 3    0.323591  0.027242    0.433503    0.432275   0.444003     0.443829
# 4    0.321503  0.049268    0.425567    0.420999   0.439146     0.429965
# ..        ...       ...         ...         ...        ...          ...
# 781  1.000000  0.129402    0.663736    0.677921   0.667338     0.668704
# 782  1.000000  0.116795    0.655780    0.664052   0.663516     0.677406
# 783  1.000000  0.100275    0.673172    0.676400   0.687213     0.679961
# 784  1.000000  0.091146    0.669671    0.666618   0.679887     0.677515
# 785  1.000000  0.078829    0.679776    0.687028   0.698433     0.699608
#
#      Adj Close_SP500  Volume_SP500  USRECD
# 0           0.446537      0.207162       0
# 1           0.442680      0.247149       0
# 2           0.448878      0.230680       0
# 3           0.443829      0.279650       0
# 4           0.429965      0.266300       0
# ..               ...           ...     ...
# 781         0.668704      0.397233       0
# 782         0.677406      0.347943       0
# 783         0.679961      0.305570       0
# 784         0.677515      0.279096       0
# 785         0.699608      0.294894       0
#
# [786 rows x 26 columns]

# %%
df_x_test = df_test[df_test.columns[2:25]]
df_x_test.head()
# Out:
#        Open      High       Low     Close  Adj Close    Volume  \
# 0  0.347160  0.349858  0.354052  0.351192   0.351192  0.003255
# 1  0.346792  0.347252  0.347124  0.345481   0.345481  0.003274
# 2  0.345281  0.349727  0.351356  0.353272   0.353272  0.003149
# 3  0.346516  0.354383  0.352805  0.358308   0.358308  0.004623
# 4  0.352061  0.353137  0.348110  0.345891   0.345891  0.006641
#
#    percentile_last_30   Open_t1   High_t1    Low_t1  ...    T10Y2Y    T10YIE  \
# 0            0.966667  0.344464  0.347865  0.351047  ...  0.466165  0.460317
# 1            0.800000  0.347040  0.349858  0.354052  ...  0.454887  0.456349
# 2            1.000000  0.346672  0.347252  0.347124  ...  0.454887  0.456349
# 3            1.000000  0.345161  0.349727  0.351356  ...  0.451128  0.448413
# 4            0.733333  0.346396  0.354383  0.352805  ...  0.447368  0.440476
#
#         DFF    VIXCLS  Open_SP500  High_SP500  Low_SP500  Close_SP500  \
# 0  0.321503  0.000000    0.432560    0.428915   0.453713     0.446537
# 1  0.323591  0.016664    0.428964    0.426659   0.449640     0.442680
# 2  0.323591  0.010143    0.433479    0.434010   0.458612     0.448878
# 3  0.323591  0.027242    0.433503    0.432275   0.444003     0.443829
# 4  0.321503  0.049268    0.425567    0.420999   0.439146     0.429965
#
#    Adj Close_SP500  Volume_SP500
# 0         0.446537      0.207162
# 1         0.442680      0.247149
# 2         0.448878      0.230680
# 3         0.443829      0.279650
# 4         0.429965      0.266300
#
# [5 rows x 23 columns]

# %%
df_y_test = df_test[df_test.columns[25:26]]
df_y_test.head()
# Out:
#    USRECD
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ### Accuracy Score and Classification Report for the trained model on the test set

# %%
import pickle
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

#test_data_file = open("labelled_scaled_period2.csv","rb")
x_test,y_test = df_x_test.to_numpy(),df_y_test.to_numpy()
#test_data_file.close()

# Test accuracy on our test dataset
y_pred_test = best_model.predict(x_test)

# Compute accuracy on test data
test_accuracy = accuracy_score(y_pred_test, y_test.flatten())

# Print accuracy on the test data

print (f"Test accuracy for model {test_accuracy}")
print (f"Classification matrix: {classification_report(y_test.flatten(), y_pred_test)}")
# Out:
# Test accuracy for model 0.4389312977099237
# Classification matrix:               precision    recall  f1-score   support
#
#            0       1.00      0.41      0.58       743
#            1       0.09      1.00      0.16        43
#
#     accuracy                           0.44       786
#    macro avg       0.54      0.70      0.37       786
# weighted avg       0.95      0.44      0.56       786
